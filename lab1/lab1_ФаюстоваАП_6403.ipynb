# %% [markdown]
# <a href="https://colab.research.google.com/github/Alenafaust/Big_data_fayustova_6403/blob/main/lab1/lab1_%D0%A4%D0%B0%D1%8E%D1%81%D1%82%D0%BE%D0%B2%D0%B0%D0%90%D0%9F_6403.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Запуск анализа данных в неинтерактивном режиме

# %%
# %cd /content/drive/MyDrive/Большие_данные_лр1
# Out:
# /content/drive/MyDrive/Большие_данные_лр1

# %%
# !spark-submit --master local[*] /content/drive/MyDrive/Большие_данные_лр1/L1_noninteractive_bike_analysis_python.py
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 26/04/04 10:51:15 INFO SparkContext: Running Spark version 4.0.2
# 26/04/04 10:51:15 INFO SparkContext: OS info Linux, 6.6.113+, amd64
# 26/04/04 10:51:15 INFO SparkContext: Java version 17.0.18
# 26/04/04 10:51:15 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 26/04/04 10:51:15 INFO ResourceUtils: ==============================================================
# 26/04/04 10:51:15 INFO ResourceUtils: No custom resources configured for spark.driver.
# 26/04/04 10:51:15 INFO ResourceUtils: ==============================================================
# 26/04/04 10:51:15 INFO SparkContext: Submitted application: Lab1_Script
# 26/04/04 10:51:15 INFO ResourceProfile: Default ResourceProfile created, executor resources: Map(cores -> name: cores, amount: 1, script: , vendor: , memory -> name: memory, amount: 1024, script: , vendor: , offHeap -> name: offHeap, amount: 0, script: , vendor: ), task resources: Map(cpus -> name: cpus, amount: 1.0)
# 26/04/04 10:51:15 INFO ResourceProfile: Limiting resource is cpu
# 26/04/04 10:51:15 INFO ResourceProfileManager: Added ResourceProfile id: 0
# 26/04/04 10:51:16 INFO SecurityManager: Changing view acls to: root
# 26/04/04 10:51:16 INFO SecurityManager: Changing modify acls to: root
# 26/04/04 10:51:16 INFO SecurityManager: Changing view acls groups to: root
# 26/04/04 10:51:16 INFO SecurityManager: Changing modify acls groups to: root
# 26/04/04 10:51:16 INFO SecurityManager: SecurityManager: authentication disabled; ui acls disabled; users with view permissions: root groups with view permissions: EMPTY; users with modify permissions: root; groups with modify permissions: EMPTY; RPC SSL disabled
# 26/04/04 10:51:16 INFO Utils: Successfully started service 'sparkDriver' on port 45841.
# 26/04/04 10:51:16 INFO SparkEnv: Registering MapOutputTracker
# 26/04/04 10:51:17 INFO SparkEnv: Registering BlockManagerMaster
# 26/04/04 10:51:17 INFO BlockManagerMasterEndpoint: Using org.apache.spark.storage.DefaultTopologyMapper for getting topology information
# 26/04/04 10:51:17 INFO BlockManagerMasterEndpoint: BlockManagerMasterEndpoint up
# 26/04/04 10:51:17 INFO SparkEnv: Registering BlockManagerMasterHeartbeat
# 26/04/04 10:51:17 INFO DiskBlockManager: Created local directory at /tmp/blockmgr-d746c1d3-9653-4eb0-bb7b-cc6e43a6c73e
# 26/04/04 10:51:17 INFO SparkEnv: Registering OutputCommitCoordinator
# 26/04/04 10:51:17 INFO JettyUtils: Start Jetty 0.0.0.0:4040 for SparkUI
# 26/04/04 10:51:17 INFO Utils: Successfully started service 'SparkUI' on port 4040.
# 26/04/04 10:51:17 INFO SecurityManager: Changing view acls to: root
# 26/04/04 10:51:17 INFO SecurityManager: Changing modify acls to: root
# 26/04/04 10:51:17 INFO SecurityManager: Changing view acls groups to: root
# 26/04/04 10:51:17 INFO SecurityManager: Changing modify acls groups to: root
# 26/04/04 10:51:17 INFO SecurityManager: SecurityManager: authentication disabled; ui acls disabled; users with view permissions: root groups with view permissions: EMPTY; users with modify permissions: root; groups with modify permissions: EMPTY; RPC SSL disabled
# 26/04/04 10:51:18 INFO Executor: Starting executor ID driver on host f835b7231555
# 26/04/04 10:51:18 INFO Executor: OS info Linux, 6.6.113+, amd64
# 26/04/04 10:51:18 INFO Executor: Java version 17.0.18
# 26/04/04 10:51:18 INFO Executor: Starting executor with user classpath (userClassPathFirst = false): ''
# 26/04/04 10:51:18 INFO Executor: Created or updated repl class loader org.apache.spark.util.MutableURLClassLoader@40e85742 for default.
# 26/04/04 10:51:18 INFO Utils: Successfully started service 'org.apache.spark.network.netty.NettyBlockTransferService' on port 33383.
# 26/04/04 10:51:18 INFO NettyBlockTransferService: Server created on f835b7231555:33383
# 26/04/04 10:51:18 INFO BlockManager: Using org.apache.spark.storage.RandomBlockReplicationPolicy for block replication policy
# 26/04/04 10:51:18 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, f835b7231555, 33383, None)
# 26/04/04 10:51:18 INFO BlockManagerMasterEndpoint: Registering block manager f835b7231555:33383 with 434.4 MiB RAM, BlockManagerId(driver, f835b7231555, 33383, None)
# 26/04/04 10:51:18 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, f835b7231555, 33383, None)
# 26/04/04 10:51:18 INFO BlockManager: Initialized BlockManager: BlockManagerId(driver, f835b7231555, 33383, None)
# 26/04/04 10:51:19 INFO MemoryStore: MemoryStore started with capacity 434.4 MiB
# 26/04/04 10:51:19 INFO MemoryStore: Block broadcast_0 stored as values in memory (estimated size 242.3 KiB, free 434.2 MiB)
# 26/04/04 10:51:19 INFO MemoryStore: Block broadcast_0_piece0 stored as bytes in memory (estimated size 36.9 KiB, free 434.1 MiB)
# 26/04/04 10:51:19 INFO SparkContext: Created broadcast 0 from textFile at NativeMethodAccessorImpl.java:0
# 26/04/04 10:51:19 INFO FileInputFormat: Total input files to process : 1
# 26/04/04 10:51:20 INFO SparkContext: Starting job: runJob at PythonRDD.scala:189
# 26/04/04 10:51:20 INFO DAGScheduler: Got job 0 (runJob at PythonRDD.scala:189) with 1 output partitions
# 26/04/04 10:51:20 INFO DAGScheduler: Final stage: ResultStage 0 (runJob at PythonRDD.scala:189)
# 26/04/04 10:51:20 INFO DAGScheduler: Parents of final stage: List()
# 26/04/04 10:51:20 INFO DAGScheduler: Missing parents: List()
# 26/04/04 10:51:20 INFO DAGScheduler: Submitting ResultStage 0 (PythonRDD[2] at RDD at PythonRDD.scala:56), which has no missing parents
# 26/04/04 10:51:20 INFO MemoryStore: Block broadcast_1 stored as values in memory (estimated size 8.0 KiB, free 434.1 MiB)
# 26/04/04 10:51:20 INFO MemoryStore: Block broadcast_1_piece0 stored as bytes in memory (estimated size 4.9 KiB, free 434.1 MiB)
# 26/04/04 10:51:20 INFO SparkContext: Created broadcast 1 from broadcast at DAGScheduler.scala:1676
# 26/04/04 10:51:20 INFO DAGScheduler: Submitting 1 missing tasks from ResultStage 0 (PythonRDD[2] at RDD at PythonRDD.scala:56) (first 15 tasks are for partitions Vector(0))
# 26/04/04 10:51:20 INFO TaskSchedulerImpl: Adding task set 0.0 with 1 tasks resource profile 0
# 26/04/04 10:51:20 INFO TaskSetManager: Starting task 0.0 in stage 0.0 (TID 0) (f835b7231555,executor driver, partition 0, PROCESS_LOCAL, 9723 bytes)
# 26/04/04 10:51:20 INFO Executor: Running task 0.0 in stage 0.0 (TID 0)
# 26/04/04 10:51:20 INFO HadoopRDD: Task (TID 0) input split: file:/content/drive/MyDrive/Большие_данные_лр1/data/trips.csv:0+33554432
# 26/04/04 10:51:23 INFO PythonRunner: Times: total = 1677, boot = 1240, init = 436, finish = 1
# 26/04/04 10:51:23 INFO Executor: Finished task 0.0 in stage 0.0 (TID 0). 1735 bytes result sent to driver
# 26/04/04 10:51:23 INFO TaskSetManager: Finished task 0.0 in stage 0.0 (TID 0) in 2826 ms on f835b7231555 (executor driver) (1/1)
# 26/04/04 10:51:23 INFO TaskSchedulerImpl: Removed TaskSet 0.0 whose tasks have all completed, from pool
# 26/04/04 10:51:23 INFO PythonAccumulatorV2: Connected to AccumulatorServer at host: 127.0.0.1 port: 43653
# 26/04/04 10:51:23 INFO DAGScheduler: ResultStage 0 (runJob at PythonRDD.scala:189) finished in 3095 ms
# 26/04/04 10:51:23 INFO DAGScheduler: Job 0 is finished. Cancelling potential speculative or zombie tasks for this job
# 26/04/04 10:51:23 INFO TaskSchedulerImpl: Canceling stage 0
# 26/04/04 10:51:23 INFO TaskSchedulerImpl: Killing all running tasks in stage 0: Stage finished
# 26/04/04 10:51:23 INFO DAGScheduler: Job 0 finished: runJob at PythonRDD.scala:189, took 3237.222479 ms
# 26/04/04 10:51:23 INFO MemoryStore: Block broadcast_2 stored as values in memory (estimated size 242.3 KiB, free 433.9 MiB)
# 26/04/04 10:51:23 INFO MemoryStore: Block broadcast_2_piece0 stored as bytes in memory (estimated size 36.9 KiB, free 433.8 MiB)
# 26/04/04 10:51:23 INFO SparkContext: Created broadcast 2 from textFile at NativeMethodAccessorImpl.java:0
# 26/04/04 10:51:23 INFO FileInputFormat: Total input files to process : 1
# 26/04/04 10:51:23 INFO SparkContext: Starting job: runJob at PythonRDD.scala:189
# 26/04/04 10:51:23 INFO DAGScheduler: Got job 1 (runJob at PythonRDD.scala:189) with 1 output partitions
# 26/04/04 10:51:23 INFO DAGScheduler: Final stage: ResultStage 1 (runJob at PythonRDD.scala:189)
# 26/04/04 10:51:23 INFO DAGScheduler: Parents of final stage: List()
# 26/04/04 10:51:23 INFO DAGScheduler: Missing parents: List()
# 26/04/04 10:51:23 INFO DAGScheduler: Submitting ResultStage 1 (PythonRDD[5] at RDD at PythonRDD.scala:56), which has no missing parents
# 26/04/04 10:51:23 INFO MemoryStore: Block broadcast_3 stored as values in memory (estimated size 8.0 KiB, free 433.8 MiB)
# 26/04/04 10:51:23 INFO MemoryStore: Block broadcast_3_piece0 stored as bytes in memory (estimated size 4.9 KiB, free 433.8 MiB)
# 26/04/04 10:51:23 INFO SparkContext: Created broadcast 3 from broadcast at DAGScheduler.scala:1676
# 26/04/04 10:51:23 INFO DAGScheduler: Submitting 1 missing tasks from ResultStage 1 (PythonRDD[5] at RDD at PythonRDD.scala:56) (first 15 tasks are for partitions Vector(0))
# 26/04/04 10:51:23 INFO TaskSchedulerImpl: Adding task set 1.0 with 1 tasks resource profile 0
# 26/04/04 10:51:23 INFO TaskSetManager: Starting task 0.0 in stage 1.0 (TID 1) (f835b7231555,executor driver, partition 0, PROCESS_LOCAL, 9726 bytes)
# 26/04/04 10:51:23 INFO Executor: Running task 0.0 in stage 1.0 (TID 1)
# 26/04/04 10:51:23 INFO HadoopRDD: Task (TID 1) input split: file:/content/drive/MyDrive/Большие_данные_лр1/data/stations.csv:0+2823
# 26/04/04 10:51:23 INFO PythonRunner: Times: total = 292, boot = 9, init = 282, finish = 1
# 26/04/04 10:51:23 INFO Executor: Finished task 0.0 in stage 1.0 (TID 1). 1565 bytes result sent to driver
# 26/04/04 10:51:23 INFO TaskSetManager: Finished task 0.0 in stage 1.0 (TID 1) in 354 ms on f835b7231555 (executor driver) (1/1)
# 26/04/04 10:51:23 INFO TaskSchedulerImpl: Removed TaskSet 1.0 whose tasks have all completed, from pool
# 26/04/04 10:51:23 INFO DAGScheduler: ResultStage 1 (runJob at PythonRDD.scala:189) finished in 382 ms
# 26/04/04 10:51:23 INFO DAGScheduler: Job 1 is finished. Cancelling potential speculative or zombie tasks for this job
# 26/04/04 10:51:23 INFO TaskSchedulerImpl: Canceling stage 1
# 26/04/04 10:51:23 INFO TaskSchedulerImpl: Killing all running tasks in stage 1: Stage finished
# 26/04/04 10:51:23 INFO DAGScheduler: Job 1 finished: runJob at PythonRDD.scala:189, took 394.848864 ms
# 26/04/04 10:51:23 INFO SparkContext: Starting job: sortBy at /content/drive/MyDrive/Большие_данные_лр1/L1_noninteractive_bike_analysis_python.py:111
# 26/04/04 10:51:23 INFO DAGScheduler: Registering RDD 7 (aggregateByKey at /content/drive/MyDrive/Большие_данные_лр1/L1_noninteractive_bike_analysis_python.py:106) as input to shuffle 0
# 26/04/04 10:51:23 INFO DAGScheduler: Got job 2 (sortBy at /content/drive/MyDrive/Большие_данные_лр1/L1_noninteractive_bike_analysis_python.py:111) with 3 output partitions
# 26/04/04 10:51:23 INFO DAGScheduler: Final stage: ResultStage 3 (sortBy at /content/drive/MyDrive/Большие_данные_лр1/L1_noninteractive_bike_analysis_python.py:111)
# 26/04/04 10:51:23 INFO DAGScheduler: Parents of final stage: List(ShuffleMapStage 2)
# 26/04/04 10:51:23 INFO DAGScheduler: Missing parents: List(ShuffleMapStage 2)
# 26/04/04 10:51:24 INFO DAGScheduler: Submitting ShuffleMapStage 2 (PairwiseRDD[7] at aggregateByKey at /content/drive/MyDrive/Большие_данные_лр1/L1_noninteractive_bike_analysis_python.py:106), which has no missing parents
# 26/04/04 10:51:24 INFO MemoryStore: Block broadcast_4 stored as values in memory (estimated size 18.8 KiB, free 433.8 MiB)
# 26/04/04 10:51:24 INFO MemoryStore: Block broadcast_4_piece0 stored as bytes in memory (estimated size 10.3 KiB, free 433.8 MiB)
# 26/04/04 10:51:24 INFO SparkContext: Created broadcast 4 from broadcast at DAGScheduler.scala:1676
# 26/04/04 10:51:24 INFO DAGScheduler: Submitting 3 missing tasks from ShuffleMapStage 2 (PairwiseRDD[7] at aggregateByKey at /content/drive/MyDrive/Большие_данные_лр1/L1_noninteractive_bike_analysis_python.py:106) (first 15 tasks are for partitions Vector(0, 1, 2))
# 26/04/04 10:51:24 INFO TaskSchedulerImpl: Adding task set 2.0 with 3 tasks resource profile 0
# 26/04/04 10:51:24 INFO TaskSetManager: Starting task 0.0 in stage 2.0 (TID 2) (f835b7231555,executor driver, partition 0, PROCESS_LOCAL, 9712 bytes)
# 26/04/04 10:51:24 INFO TaskSetManager: Starting task 1.0 in stage 2.0 (TID 3) (f835b7231555,executor driver, partition 1, PROCESS_LOCAL, 9712 bytes)
# 26/04/04 10:51:24 INFO Executor: Running task 0.0 in stage 2.0 (TID 2)
# 26/04/04 10:51:24 INFO Executor: Running task 1.0 in stage 2.0 (TID 3)
# 26/04/04 10:51:24 INFO HadoopRDD: Task (TID 2) input split: file:/content/drive/MyDrive/Большие_данные_лр1/data/trips.csv:0+33554432
# 26/04/04 10:51:24 INFO HadoopRDD: Task (TID 3) input split: file:/content/drive/MyDrive/Большие_данные_лр1/data/trips.csv:33554432+33554432
# 26/04/04 10:51:24 INFO SecurityManager: Changing view acls to: root
# 26/04/04 10:51:24 INFO SecurityManager: Changing modify acls to: root
# 26/04/04 10:51:24 INFO SecurityManager: Changing view acls groups to: root
# 26/04/04 10:51:24 INFO SecurityManager: Changing modify acls groups to: root
# 26/04/04 10:51:24 INFO SecurityManager: SecurityManager: authentication disabled; ui acls disabled; users with view permissions: root groups with view permissions: EMPTY; users with modify permissions: root; groups with modify permissions: EMPTY; RPC SSL disabled
# 26/04/04 10:51:40 INFO PythonRunner: Times: total = 15568, boot = 13, init = 565, finish = 14990
# 26/04/04 10:51:40 INFO PythonRunner: Times: total = 16318, boot = 22, init = 487, finish = 15809
# 26/04/04 10:51:40 INFO Executor: Finished task 1.0 in stage 2.0 (TID 3). 1773 bytes result sent to driver
# 26/04/04 10:51:40 INFO Executor: Finished task 0.0 in stage 2.0 (TID 2). 1773 bytes result sent to driver
# 26/04/04 10:51:40 INFO TaskSetManager: Starting task 2.0 in stage 2.0 (TID 4) (f835b7231555,executor driver, partition 2, PROCESS_LOCAL, 9712 bytes)
# 26/04/04 10:51:40 INFO Executor: Running task 2.0 in stage 2.0 (TID 4)
# 26/04/04 10:51:40 INFO TaskSetManager: Finished task 1.0 in stage 2.0 (TID 3) in 16682 ms on f835b7231555 (executor driver) (1/3)
# 26/04/04 10:51:40 INFO TaskSetManager: Finished task 0.0 in stage 2.0 (TID 2) in 16695 ms on f835b7231555 (executor driver) (2/3)
# 26/04/04 10:51:40 INFO HadoopRDD: Task (TID 4) input split: file:/content/drive/MyDrive/Большие_данные_лр1/data/trips.csv:67108864+13099967
# 26/04/04 10:51:44 INFO PythonRunner: Times: total = 3237, boot = -1022, init = 1304, finish = 2955
# 26/04/04 10:51:44 INFO Executor: Finished task 2.0 in stage 2.0 (TID 4). 1687 bytes result sent to driver
# 26/04/04 10:51:44 INFO TaskSetManager: Finished task 2.0 in stage 2.0 (TID 4) in 3433 ms on f835b7231555 (executor driver) (3/3)
# 26/04/04 10:51:44 INFO TaskSchedulerImpl: Removed TaskSet 2.0 whose tasks have all completed, from pool
# 26/04/04 10:51:44 INFO DAGScheduler: ShuffleMapStage 2 (aggregateByKey at /content/drive/MyDrive/Большие_данные_лр1/L1_noninteractive_bike_analysis_python.py:106) finished in 20166 ms
# 26/04/04 10:51:44 INFO DAGScheduler: looking for newly runnable stages
# 26/04/04 10:51:44 INFO DAGScheduler: running: HashSet()
# 26/04/04 10:51:44 INFO DAGScheduler: waiting: HashSet(ResultStage 3)
# 26/04/04 10:51:44 INFO DAGScheduler: failed: HashSet()
# 26/04/04 10:51:44 INFO DAGScheduler: Submitting ResultStage 3 (PythonRDD[10] at sortBy at /content/drive/MyDrive/Большие_данные_лр1/L1_noninteractive_bike_analysis_python.py:111), which has no missing parents
# 26/04/04 10:51:44 INFO MemoryStore: Block broadcast_5 stored as values in memory (estimated size 14.9 KiB, free 433.8 MiB)
# 26/04/04 10:51:44 INFO MemoryStore: Block broadcast_5_piece0 stored as bytes in memory (estimated size 7.7 KiB, free 433.8 MiB)
# 26/04/04 10:51:44 INFO SparkContext: Created broadcast 5 from broadcast at DAGScheduler.scala:1676
# 26/04/04 10:51:44 INFO DAGScheduler: Submitting 3 missing tasks from ResultStage 3 (PythonRDD[10] at sortBy at /content/drive/MyDrive/Большие_данные_лр1/L1_noninteractive_bike_analysis_python.py:111) (first 15 tasks are for partitions Vector(0, 1, 2))
# 26/04/04 10:51:44 INFO TaskSchedulerImpl: Adding task set 3.0 with 3 tasks resource profile 0
# 26/04/04 10:51:44 INFO TaskSetManager: Starting task 0.0 in stage 3.0 (TID 5) (f835b7231555,executor driver, partition 0, NODE_LOCAL, 9449 bytes)
# 26/04/04 10:51:44 INFO TaskSetManager: Starting task 1.0 in stage 3.0 (TID 6) (f835b7231555,executor driver, partition 1, NODE_LOCAL, 9449 bytes)
# 26/04/04 10:51:44 INFO Executor: Running task 0.0 in stage 3.0 (TID 5)
# 26/04/04 10:51:44 INFO Executor: Running task 1.0 in stage 3.0 (TID 6)
# 26/04/04 10:51:44 INFO ShuffleBlockFetcherIterator: Getting 3 (2.2 KiB) non-empty blocks including 3 (2.2 KiB) local and 0 (0.0 B) host-local and 0 (0.0 B) push-merged-local and 0 (0.0 B) remote blocks
# 26/04/04 10:51:44 INFO ShuffleBlockFetcherIterator: Getting 3 (2021.0 B) non-empty blocks including 3 (2021.0 B) local and 0 (0.0 B) host-local and 0 (0.0 B) push-merged-local and 0 (0.0 B) remote blocks
# 26/04/04 10:51:44 INFO ShuffleBlockFetcherIterator: Started 0 remote fetches in 58 ms
# 26/04/04 10:51:44 INFO ShuffleBlockFetcherIterator: Started 0 remote fetches in 61 ms
# 26/04/04 10:51:45 INFO PythonRunner: Times: total = 530, boot = -516, init = 1042, finish = 4
# 26/04/04 10:51:45 INFO Executor: Finished task 0.0 in stage 3.0 (TID 5). 2159 bytes result sent to driver
# 26/04/04 10:51:45 INFO TaskSetManager: Starting task 2.0 in stage 3.0 (TID 7) (f835b7231555,executor driver, partition 2, NODE_LOCAL, 9449 bytes)
# 26/04/04 10:51:45 INFO Executor: Running task 2.0 in stage 3.0 (TID 7)
# 26/04/04 10:51:45 INFO TaskSetManager: Finished task 0.0 in stage 3.0 (TID 5) in 846 ms on f835b7231555 (executor driver) (1/3)
# 26/04/04 10:51:45 INFO ShuffleBlockFetcherIterator: Getting 3 (3.4 KiB) non-empty blocks including 3 (3.4 KiB) local and 0 (0.0 B) host-local and 0 (0.0 B) push-merged-local and 0 (0.0 B) remote blocks
# 26/04/04 10:51:45 INFO ShuffleBlockFetcherIterator: Started 0 remote fetches in 7 ms
# 26/04/04 10:51:45 INFO PythonRunner: Times: total = 669, boot = -4057, init = 4725, finish = 1
# 26/04/04 10:51:45 INFO Executor: Finished task 1.0 in stage 3.0 (TID 6). 2159 bytes result sent to driver
# 26/04/04 10:51:45 INFO TaskSetManager: Finished task 1.0 in stage 3.0 (TID 6) in 953 ms on f835b7231555 (executor driver) (2/3)
# 26/04/04 10:51:45 INFO PythonRunner: Times: total = 286, boot = -3, init = 288, finish = 1
# 26/04/04 10:51:45 INFO Executor: Finished task 2.0 in stage 3.0 (TID 7). 2159 bytes result sent to driver
# 26/04/04 10:51:45 INFO TaskSetManager: Finished task 2.0 in stage 3.0 (TID 7) in 425 ms on f835b7231555 (executor driver) (3/3)
# 26/04/04 10:51:45 INFO TaskSchedulerImpl: Removed TaskSet 3.0 whose tasks have all completed, from pool
# 26/04/04 10:51:45 INFO DAGScheduler: ResultStage 3 (sortBy at /content/drive/MyDrive/Большие_данные_лр1/L1_noninteractive_bike_analysis_python.py:111) finished in 1323 ms
# 26/04/04 10:51:45 INFO DAGScheduler: Job 2 is finished. Cancelling potential speculative or zombie tasks for this job
# 26/04/04 10:51:45 INFO TaskSchedulerImpl: Canceling stage 3
# 26/04/04 10:51:45 INFO TaskSchedulerImpl: Killing all running tasks in stage 3: Stage finished
# 26/04/04 10:51:45 INFO DAGScheduler: Job 2 finished: sortBy at /content/drive/MyDrive/Большие_данные_лр1/L1_noninteractive_bike_analysis_python.py:111, took 21673.095565 ms
# 26/04/04 10:51:45 INFO SparkContext: Starting job: sortBy at /content/drive/MyDrive/Большие_данные_лр1/L1_noninteractive_bike_analysis_python.py:111
# 26/04/04 10:51:45 INFO DAGScheduler: Got job 3 (sortBy at /content/drive/MyDrive/Большие_данные_лр1/L1_noninteractive_bike_analysis_python.py:111) with 3 output partitions
# 26/04/04 10:51:45 INFO DAGScheduler: Final stage: ResultStage 5 (sortBy at /content/drive/MyDrive/Большие_данные_лр1/L1_noninteractive_bike_analysis_python.py:111)
# 26/04/04 10:51:45 INFO DAGScheduler: Parents of final stage: List(ShuffleMapStage 4)
# 26/04/04 10:51:45 INFO DAGScheduler: Missing parents: List()
# 26/04/04 10:51:45 INFO DAGScheduler: Submitting ResultStage 5 (PythonRDD[11] at sortBy at /content/drive/MyDrive/Большие_данные_лр1/L1_noninteractive_bike_analysis_python.py:111), which has no missing parents
# 26/04/04 10:51:45 INFO MemoryStore: Block broadcast_6 stored as values in memory (estimated size 13.8 KiB, free 433.8 MiB)
# 26/04/04 10:51:45 INFO MemoryStore: Block broadcast_6_piece0 stored as bytes in memory (estimated size 7.4 KiB, free 433.8 MiB)
# 26/04/04 10:51:45 INFO SparkContext: Created broadcast 6 from broadcast at DAGScheduler.scala:1676
# 26/04/04 10:51:45 INFO DAGScheduler: Submitting 3 missing tasks from ResultStage 5 (PythonRDD[11] at sortBy at /content/drive/MyDrive/Большие_данные_лр1/L1_noninteractive_bike_analysis_python.py:111) (first 15 tasks are for partitions Vector(0, 1, 2))
# 26/04/04 10:51:45 INFO TaskSchedulerImpl: Adding task set 5.0 with 3 tasks resource profile 0
# 26/04/04 10:51:45 INFO TaskSetManager: Starting task 0.0 in stage 5.0 (TID 8) (f835b7231555,executor driver, partition 0, NODE_LOCAL, 9449 bytes)
# 26/04/04 10:51:45 INFO TaskSetManager: Starting task 1.0 in stage 5.0 (TID 9) (f835b7231555,executor driver, partition 1, NODE_LOCAL, 9449 bytes)
# 26/04/04 10:51:45 INFO Executor: Running task 1.0 in stage 5.0 (TID 9)
# 26/04/04 10:51:45 INFO Executor: Running task 0.0 in stage 5.0 (TID 8)
# 26/04/04 10:51:45 INFO ShuffleBlockFetcherIterator: Getting 3 (2.2 KiB) non-empty blocks including 3 (2.2 KiB) local and 0 (0.0 B) host-local and 0 (0.0 B) push-merged-local and 0 (0.0 B) remote blocks
# 26/04/04 10:51:45 INFO ShuffleBlockFetcherIterator: Started 0 remote fetches in 1 ms
# 26/04/04 10:51:45 INFO ShuffleBlockFetcherIterator: Getting 3 (2021.0 B) non-empty blocks including 3 (2021.0 B) local and 0 (0.0 B) host-local and 0 (0.0 B) push-merged-local and 0 (0.0 B) remote blocks
# 26/04/04 10:51:45 INFO ShuffleBlockFetcherIterator: Started 0 remote fetches in 5 ms
# 26/04/04 10:51:46 INFO PythonRunner: Times: total = 409, boot = -426, init = 835, finish = 0
# 26/04/04 10:51:46 INFO Executor: Finished task 0.0 in stage 5.0 (TID 8). 2407 bytes result sent to driver
# 26/04/04 10:51:46 INFO TaskSetManager: Starting task 2.0 in stage 5.0 (TID 10) (f835b7231555,executor driver, partition 2, NODE_LOCAL, 9449 bytes)
# 26/04/04 10:51:46 INFO Executor: Running task 2.0 in stage 5.0 (TID 10)
# 26/04/04 10:51:46 INFO TaskSetManager: Finished task 0.0 in stage 5.0 (TID 8) in 488 ms on f835b7231555 (executor driver) (1/3)
# 26/04/04 10:51:46 INFO ShuffleBlockFetcherIterator: Getting 3 (3.4 KiB) non-empty blocks including 3 (3.4 KiB) local and 0 (0.0 B) host-local and 0 (0.0 B) push-merged-local and 0 (0.0 B) remote blocks
# 26/04/04 10:51:46 INFO ShuffleBlockFetcherIterator: Started 0 remote fetches in 1 ms
# 26/04/04 10:51:46 INFO PythonRunner: Times: total = 585, boot = -193, init = 776, finish = 2
# 26/04/04 10:51:46 INFO Executor: Finished task 1.0 in stage 5.0 (TID 9). 2355 bytes result sent to driver
# 26/04/04 10:51:46 INFO TaskSetManager: Finished task 1.0 in stage 5.0 (TID 9) in 670 ms on f835b7231555 (executor driver) (2/3)
# 26/04/04 10:51:46 INFO PythonRunner: Times: total = 415, boot = 16, init = 399, finish = 0
# 26/04/04 10:51:46 INFO Executor: Finished task 2.0 in stage 5.0 (TID 10). 2507 bytes result sent to driver
# 26/04/04 10:51:46 INFO TaskSetManager: Finished task 2.0 in stage 5.0 (TID 10) in 518 ms on f835b7231555 (executor driver) (3/3)
# 26/04/04 10:51:46 INFO TaskSchedulerImpl: Removed TaskSet 5.0 whose tasks have all completed, from pool
# 26/04/04 10:51:46 INFO DAGScheduler: ResultStage 5 (sortBy at /content/drive/MyDrive/Большие_данные_лр1/L1_noninteractive_bike_analysis_python.py:111) finished in 1027 ms
# 26/04/04 10:51:46 INFO DAGScheduler: Job 3 is finished. Cancelling potential speculative or zombie tasks for this job
# 26/04/04 10:51:46 INFO TaskSchedulerImpl: Canceling stage 5
# 26/04/04 10:51:46 INFO TaskSchedulerImpl: Killing all running tasks in stage 5: Stage finished
# 26/04/04 10:51:46 INFO DAGScheduler: Job 3 finished: sortBy at /content/drive/MyDrive/Большие_данные_лр1/L1_noninteractive_bike_analysis_python.py:111, took 1049.692393 ms
# 26/04/04 10:51:47 INFO deprecation: mapred.output.dir is deprecated. Instead, use mapreduce.output.fileoutputformat.outputdir
# 26/04/04 10:51:47 INFO HadoopMapRedCommitProtocol: Using output committer class org.apache.hadoop.mapred.FileOutputCommitter
# 26/04/04 10:51:47 INFO FileOutputCommitter: File Output Committer Algorithm version is 1
# 26/04/04 10:51:47 INFO FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 26/04/04 10:51:47 INFO SparkContext: Starting job: runJob at SparkHadoopWriter.scala:85
# 26/04/04 10:51:47 INFO DAGScheduler: Registering RDD 13 (sortBy at /content/drive/MyDrive/Большие_данные_лр1/L1_noninteractive_bike_analysis_python.py:111) as input to shuffle 1
# 26/04/04 10:51:47 INFO DAGScheduler: Got job 4 (runJob at SparkHadoopWriter.scala:85) with 3 output partitions
# 26/04/04 10:51:47 INFO DAGScheduler: Final stage: ResultStage 8 (runJob at SparkHadoopWriter.scala:85)
# 26/04/04 10:51:47 INFO DAGScheduler: Parents of final stage: List(ShuffleMapStage 7)
# 26/04/04 10:51:47 INFO DAGScheduler: Missing parents: List(ShuffleMapStage 7)
# 26/04/04 10:51:47 INFO DAGScheduler: Submitting ShuffleMapStage 7 (PairwiseRDD[13] at sortBy at /content/drive/MyDrive/Большие_данные_лр1/L1_noninteractive_bike_analysis_python.py:111), which has no missing parents
# 26/04/04 10:51:47 INFO MemoryStore: Block broadcast_7 stored as values in memory (estimated size 15.5 KiB, free 433.8 MiB)
# 26/04/04 10:51:47 INFO MemoryStore: Block broadcast_7_piece0 stored as bytes in memory (estimated size 8.7 KiB, free 433.8 MiB)
# 26/04/04 10:51:47 INFO SparkContext: Created broadcast 7 from broadcast at DAGScheduler.scala:1676
# 26/04/04 10:51:47 INFO DAGScheduler: Submitting 3 missing tasks from ShuffleMapStage 7 (PairwiseRDD[13] at sortBy at /content/drive/MyDrive/Большие_данные_лр1/L1_noninteractive_bike_analysis_python.py:111) (first 15 tasks are for partitions Vector(0, 1, 2))
# 26/04/04 10:51:47 INFO TaskSchedulerImpl: Adding task set 7.0 with 3 tasks resource profile 0
# 26/04/04 10:51:47 INFO TaskSetManager: Starting task 0.0 in stage 7.0 (TID 11) (f835b7231555,executor driver, partition 0, NODE_LOCAL, 9438 bytes)
# 26/04/04 10:51:47 INFO TaskSetManager: Starting task 1.0 in stage 7.0 (TID 12) (f835b7231555,executor driver, partition 1, NODE_LOCAL, 9438 bytes)
# 26/04/04 10:51:47 INFO Executor: Running task 0.0 in stage 7.0 (TID 11)
# 26/04/04 10:51:47 INFO Executor: Running task 1.0 in stage 7.0 (TID 12)
# 26/04/04 10:51:47 INFO ShuffleBlockFetcherIterator: Getting 3 (2021.0 B) non-empty blocks including 3 (2021.0 B) local and 0 (0.0 B) host-local and 0 (0.0 B) push-merged-local and 0 (0.0 B) remote blocks
# 26/04/04 10:51:47 INFO ShuffleBlockFetcherIterator: Started 0 remote fetches in 5 ms
# 26/04/04 10:51:47 INFO ShuffleBlockFetcherIterator: Getting 3 (2.2 KiB) non-empty blocks including 3 (2.2 KiB) local and 0 (0.0 B) host-local and 0 (0.0 B) push-merged-local and 0 (0.0 B) remote blocks
# 26/04/04 10:51:47 INFO ShuffleBlockFetcherIterator: Started 0 remote fetches in 7 ms
# 26/04/04 10:51:48 INFO PythonRunner: Times: total = 604, boot = -1045, init = 1648, finish = 1
# 26/04/04 10:51:48 INFO Executor: Finished task 0.0 in stage 7.0 (TID 11). 2332 bytes result sent to driver
# 26/04/04 10:51:48 INFO TaskSetManager: Starting task 2.0 in stage 7.0 (TID 13) (f835b7231555,executor driver, partition 2, NODE_LOCAL, 9438 bytes)
# 26/04/04 10:51:48 INFO Executor: Running task 2.0 in stage 7.0 (TID 13)
# 26/04/04 10:51:48 INFO TaskSetManager: Finished task 0.0 in stage 7.0 (TID 11) in 849 ms on f835b7231555 (executor driver) (1/3)
# 26/04/04 10:51:48 INFO PythonRunner: Times: total = 645, boot = -720, init = 1364, finish = 1
# 26/04/04 10:51:48 INFO Executor: Finished task 1.0 in stage 7.0 (TID 12). 2332 bytes result sent to driver
# 26/04/04 10:51:48 INFO TaskSetManager: Finished task 1.0 in stage 7.0 (TID 12) in 886 ms on f835b7231555 (executor driver) (2/3)
# 26/04/04 10:51:48 INFO ShuffleBlockFetcherIterator: Getting 3 (3.4 KiB) non-empty blocks including 3 (3.4 KiB) local and 0 (0.0 B) host-local and 0 (0.0 B) push-merged-local and 0 (0.0 B) remote blocks
# 26/04/04 10:51:48 INFO ShuffleBlockFetcherIterator: Started 0 remote fetches in 7 ms
# 26/04/04 10:51:48 INFO PythonRunner: Times: total = 277, boot = -73, init = 349, finish = 1
# 26/04/04 10:51:48 INFO Executor: Finished task 2.0 in stage 7.0 (TID 13). 2418 bytes result sent to driver
# 26/04/04 10:51:48 INFO TaskSetManager: Finished task 2.0 in stage 7.0 (TID 13) in 466 ms on f835b7231555 (executor driver) (3/3)
# 26/04/04 10:51:48 INFO TaskSchedulerImpl: Removed TaskSet 7.0 whose tasks have all completed, from pool
# 26/04/04 10:51:48 INFO DAGScheduler: ShuffleMapStage 7 (sortBy at /content/drive/MyDrive/Большие_данные_лр1/L1_noninteractive_bike_analysis_python.py:111) finished in 1344 ms
# 26/04/04 10:51:48 INFO DAGScheduler: looking for newly runnable stages
# 26/04/04 10:51:48 INFO DAGScheduler: running: HashSet()
# 26/04/04 10:51:48 INFO DAGScheduler: waiting: HashSet(ResultStage 8)
# 26/04/04 10:51:48 INFO DAGScheduler: failed: HashSet()
# 26/04/04 10:51:48 INFO DAGScheduler: Submitting ResultStage 8 (MapPartitionsRDD[22] at saveAsTextFile at NativeMethodAccessorImpl.java:0), which has no missing parents
# 26/04/04 10:51:48 INFO MemoryStore: Block broadcast_8 stored as values in memory (estimated size 120.0 KiB, free 433.7 MiB)
# 26/04/04 10:51:48 INFO MemoryStore: Block broadcast_8_piece0 stored as bytes in memory (estimated size 45.0 KiB, free 433.7 MiB)
# 26/04/04 10:51:48 INFO SparkContext: Created broadcast 8 from broadcast at DAGScheduler.scala:1676
# 26/04/04 10:51:48 INFO DAGScheduler: Submitting 3 missing tasks from ResultStage 8 (MapPartitionsRDD[22] at saveAsTextFile at NativeMethodAccessorImpl.java:0) (first 15 tasks are for partitions Vector(0, 1, 2))
# 26/04/04 10:51:48 INFO TaskSchedulerImpl: Adding task set 8.0 with 3 tasks resource profile 0
# 26/04/04 10:51:48 INFO TaskSetManager: Starting task 0.0 in stage 8.0 (TID 14) (f835b7231555,executor driver, partition 0, NODE_LOCAL, 9449 bytes)
# 26/04/04 10:51:48 INFO TaskSetManager: Starting task 1.0 in stage 8.0 (TID 15) (f835b7231555,executor driver, partition 1, NODE_LOCAL, 9449 bytes)
# 26/04/04 10:51:48 INFO Executor: Running task 1.0 in stage 8.0 (TID 15)
# 26/04/04 10:51:48 INFO Executor: Running task 0.0 in stage 8.0 (TID 14)
# 26/04/04 10:51:49 INFO ShuffleBlockFetcherIterator: Getting 3 (1278.0 B) non-empty blocks including 3 (1278.0 B) local and 0 (0.0 B) host-local and 0 (0.0 B) push-merged-local and 0 (0.0 B) remote blocks
# 26/04/04 10:51:49 INFO ShuffleBlockFetcherIterator: Started 0 remote fetches in 1 ms
# 26/04/04 10:51:49 INFO ShuffleBlockFetcherIterator: Getting 3 (1109.0 B) non-empty blocks including 3 (1109.0 B) local and 0 (0.0 B) host-local and 0 (0.0 B) push-merged-local and 0 (0.0 B) remote blocks
# 26/04/04 10:51:49 INFO ShuffleBlockFetcherIterator: Started 0 remote fetches in 6 ms
# 26/04/04 10:51:49 INFO HadoopMapRedCommitProtocol: Using output committer class org.apache.hadoop.mapred.FileOutputCommitter
# 26/04/04 10:51:49 INFO FileOutputCommitter: File Output Committer Algorithm version is 1
# 26/04/04 10:51:49 INFO FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 26/04/04 10:51:49 INFO HadoopMapRedCommitProtocol: Using output committer class org.apache.hadoop.mapred.FileOutputCommitter
# 26/04/04 10:51:49 INFO FileOutputCommitter: File Output Committer Algorithm version is 1
# 26/04/04 10:51:49 INFO FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 26/04/04 10:51:49 INFO PythonRunner: Times: total = 593, boot = -733, init = 1325, finish = 1
# 26/04/04 10:51:49 INFO PythonRunner: Times: total = 603, boot = -317, init = 920, finish = 0
# 26/04/04 10:51:49 INFO FileOutputCommitter: Saved output of task 'attempt_202604041051474089877884075585679_0022_m_000000_0' to file:/content/drive/MyDrive/Большие_данные_лр1/avg_duration_of_start_stations/_temporary/0/task_202604041051474089877884075585679_0022_m_000000
# 26/04/04 10:51:49 INFO SparkHadoopMapRedUtil: attempt_202604041051474089877884075585679_0022_m_000000_0: Committed. Elapsed time: 23 ms.
# 26/04/04 10:51:49 INFO FileOutputCommitter: Saved output of task 'attempt_202604041051474089877884075585679_0022_m_000001_0' to file:/content/drive/MyDrive/Большие_данные_лр1/avg_duration_of_start_stations/_temporary/0/task_202604041051474089877884075585679_0022_m_000001
# 26/04/04 10:51:49 INFO SparkHadoopMapRedUtil: attempt_202604041051474089877884075585679_0022_m_000001_0: Committed. Elapsed time: 27 ms.
# 26/04/04 10:51:49 INFO Executor: Finished task 1.0 in stage 8.0 (TID 15). 2594 bytes result sent to driver
# 26/04/04 10:51:49 INFO Executor: Finished task 0.0 in stage 8.0 (TID 14). 2594 bytes result sent to driver
# 26/04/04 10:51:49 INFO TaskSetManager: Starting task 2.0 in stage 8.0 (TID 16) (f835b7231555,executor driver, partition 2, NODE_LOCAL, 9449 bytes)
# 26/04/04 10:51:49 INFO Executor: Running task 2.0 in stage 8.0 (TID 16)
# 26/04/04 10:51:49 INFO TaskSetManager: Finished task 1.0 in stage 8.0 (TID 15) in 868 ms on f835b7231555 (executor driver) (1/3)
# 26/04/04 10:51:49 INFO TaskSetManager: Finished task 0.0 in stage 8.0 (TID 14) in 877 ms on f835b7231555 (executor driver) (2/3)
# 26/04/04 10:51:49 INFO ShuffleBlockFetcherIterator: Getting 3 (1195.0 B) non-empty blocks including 3 (1195.0 B) local and 0 (0.0 B) host-local and 0 (0.0 B) push-merged-local and 0 (0.0 B) remote blocks
# 26/04/04 10:51:49 INFO ShuffleBlockFetcherIterator: Started 0 remote fetches in 3 ms
# 26/04/04 10:51:49 INFO HadoopMapRedCommitProtocol: Using output committer class org.apache.hadoop.mapred.FileOutputCommitter
# 26/04/04 10:51:49 INFO FileOutputCommitter: File Output Committer Algorithm version is 1
# 26/04/04 10:51:49 INFO FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 26/04/04 10:51:50 INFO PythonRunner: Times: total = 184, boot = -86, init = 270, finish = 0
# 26/04/04 10:51:50 INFO FileOutputCommitter: Saved output of task 'attempt_202604041051474089877884075585679_0022_m_000002_0' to file:/content/drive/MyDrive/Большие_данные_лр1/avg_duration_of_start_stations/_temporary/0/task_202604041051474089877884075585679_0022_m_000002
# 26/04/04 10:51:50 INFO SparkHadoopMapRedUtil: attempt_202604041051474089877884075585679_0022_m_000002_0: Committed. Elapsed time: 17 ms.
# 26/04/04 10:51:50 INFO Executor: Finished task 2.0 in stage 8.0 (TID 16). 2551 bytes result sent to driver
# 26/04/04 10:51:50 INFO TaskSetManager: Finished task 2.0 in stage 8.0 (TID 16) in 280 ms on f835b7231555 (executor driver) (3/3)
# 26/04/04 10:51:50 INFO TaskSchedulerImpl: Removed TaskSet 8.0 whose tasks have all completed, from pool
# 26/04/04 10:51:50 INFO DAGScheduler: ResultStage 8 (runJob at SparkHadoopWriter.scala:85) finished in 1246 ms
# 26/04/04 10:51:50 INFO DAGScheduler: Job 4 is finished. Cancelling potential speculative or zombie tasks for this job
# 26/04/04 10:51:50 INFO TaskSchedulerImpl: Canceling stage 8
# 26/04/04 10:51:50 INFO TaskSchedulerImpl: Killing all running tasks in stage 8: Stage finished
# 26/04/04 10:51:50 INFO DAGScheduler: Job 4 finished: runJob at SparkHadoopWriter.scala:85, took 2628.095817 ms
# 26/04/04 10:51:50 INFO SparkHadoopWriter: Start to commit write Job job_202604041051474089877884075585679_0022.
# 26/04/04 10:51:50 INFO SparkHadoopWriter: Write Job job_202604041051474089877884075585679_0022 committed. Elapsed time: 173 ms.
# 26/04/04 10:51:50 INFO HadoopMapRedCommitProtocol: Using output committer class org.apache.hadoop.mapred.FileOutputCommitter
# 26/04/04 10:51:50 INFO FileOutputCommitter: File Output Committer Algorithm version is 1
# 26/04/04 10:51:50 INFO FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 26/04/04 10:51:50 INFO SparkContext: Starting job: runJob at SparkHadoopWriter.scala:85
# 26/04/04 10:51:50 INFO DAGScheduler: Registering RDD 17 (reduceByKey at /content/drive/MyDrive/Большие_данные_лр1/L1_noninteractive_bike_analysis_python.py:118) as input to shuffle 2
# 26/04/04 10:51:50 INFO DAGScheduler: Got job 5 (runJob at SparkHadoopWriter.scala:85) with 3 output partitions
# 26/04/04 10:51:50 INFO DAGScheduler: Final stage: ResultStage 10 (runJob at SparkHadoopWriter.scala:85)
# 26/04/04 10:51:50 INFO DAGScheduler: Parents of final stage: List(ShuffleMapStage 9)
# 26/04/04 10:51:50 INFO DAGScheduler: Missing parents: List(ShuffleMapStage 9)
# 26/04/04 10:51:50 INFO DAGScheduler: Submitting ShuffleMapStage 9 (PairwiseRDD[17] at reduceByKey at /content/drive/MyDrive/Большие_данные_лр1/L1_noninteractive_bike_analysis_python.py:118), which has no missing parents
# 26/04/04 10:51:50 INFO MemoryStore: Block broadcast_9 stored as values in memory (estimated size 17.3 KiB, free 433.7 MiB)
# 26/04/04 10:51:50 INFO MemoryStore: Block broadcast_9_piece0 stored as bytes in memory (estimated size 9.7 KiB, free 433.6 MiB)
# 26/04/04 10:51:50 INFO SparkContext: Created broadcast 9 from broadcast at DAGScheduler.scala:1676
# 26/04/04 10:51:50 INFO DAGScheduler: Submitting 3 missing tasks from ShuffleMapStage 9 (PairwiseRDD[17] at reduceByKey at /content/drive/MyDrive/Большие_данные_лр1/L1_noninteractive_bike_analysis_python.py:118) (first 15 tasks are for partitions Vector(0, 1, 2))
# 26/04/04 10:51:50 INFO TaskSchedulerImpl: Adding task set 9.0 with 3 tasks resource profile 0
# 26/04/04 10:51:50 INFO TaskSetManager: Starting task 0.0 in stage 9.0 (TID 17) (f835b7231555,executor driver, partition 0, PROCESS_LOCAL, 9712 bytes)
# 26/04/04 10:51:50 INFO TaskSetManager: Starting task 1.0 in stage 9.0 (TID 18) (f835b7231555,executor driver, partition 1, PROCESS_LOCAL, 9712 bytes)
# 26/04/04 10:51:50 INFO Executor: Running task 0.0 in stage 9.0 (TID 17)
# 26/04/04 10:51:50 INFO Executor: Running task 1.0 in stage 9.0 (TID 18)
# 26/04/04 10:51:50 INFO HadoopRDD: Task (TID 18) input split: file:/content/drive/MyDrive/Большие_данные_лр1/data/trips.csv:33554432+33554432
# 26/04/04 10:51:50 INFO HadoopRDD: Task (TID 17) input split: file:/content/drive/MyDrive/Большие_данные_лр1/data/trips.csv:0+33554432
# 26/04/04 10:52:04 INFO PythonRunner: Times: total = 13857, boot = -453, init = 806, finish = 13504
# 26/04/04 10:52:04 INFO Executor: Finished task 1.0 in stage 9.0 (TID 18). 1730 bytes result sent to driver
# 26/04/04 10:52:04 INFO TaskSetManager: Starting task 2.0 in stage 9.0 (TID 19) (f835b7231555,executor driver, partition 2, PROCESS_LOCAL, 9712 bytes)
# 26/04/04 10:52:04 INFO TaskSetManager: Finished task 1.0 in stage 9.0 (TID 18) in 14102 ms on f835b7231555 (executor driver) (1/3)
# 26/04/04 10:52:04 INFO Executor: Running task 2.0 in stage 9.0 (TID 19)
# 26/04/04 10:52:04 INFO HadoopRDD: Task (TID 19) input split: file:/content/drive/MyDrive/Большие_данные_лр1/data/trips.csv:67108864+13099967
# 26/04/04 10:52:04 INFO PythonRunner: Times: total = 14009, boot = -747, init = 1085, finish = 13671
# 26/04/04 10:52:04 INFO Executor: Finished task 0.0 in stage 9.0 (TID 17). 1730 bytes result sent to driver
# 26/04/04 10:52:04 INFO TaskSetManager: Finished task 0.0 in stage 9.0 (TID 17) in 14179 ms on f835b7231555 (executor driver) (2/3)
# 26/04/04 10:52:07 INFO PythonRunner: Times: total = 2994, boot = -148, init = 488, finish = 2654
# 26/04/04 10:52:07 INFO Executor: Finished task 2.0 in stage 9.0 (TID 19). 1730 bytes result sent to driver
# 26/04/04 10:52:07 INFO TaskSetManager: Finished task 2.0 in stage 9.0 (TID 19) in 3178 ms on f835b7231555 (executor driver) (3/3)
# 26/04/04 10:52:07 INFO TaskSchedulerImpl: Removed TaskSet 9.0 whose tasks have all completed, from pool
# 26/04/04 10:52:07 INFO DAGScheduler: ShuffleMapStage 9 (reduceByKey at /content/drive/MyDrive/Большие_данные_лр1/L1_noninteractive_bike_analysis_python.py:118) finished in 17297 ms
# 26/04/04 10:52:07 INFO DAGScheduler: looking for newly runnable stages
# 26/04/04 10:52:07 INFO DAGScheduler: running: HashSet()
# 26/04/04 10:52:07 INFO DAGScheduler: waiting: HashSet(ResultStage 10)
# 26/04/04 10:52:07 INFO DAGScheduler: failed: HashSet()
# 26/04/04 10:52:07 INFO DAGScheduler: Submitting ResultStage 10 (MapPartitionsRDD[25] at saveAsTextFile at NativeMethodAccessorImpl.java:0), which has no missing parents
# 26/04/04 10:52:07 INFO MemoryStore: Block broadcast_10 stored as values in memory (estimated size 120.6 KiB, free 433.7 MiB)
# 26/04/04 10:52:07 INFO MemoryStore: Block broadcast_10_piece0 stored as bytes in memory (estimated size 45.3 KiB, free 433.7 MiB)
# 26/04/04 10:52:07 INFO SparkContext: Created broadcast 10 from broadcast at DAGScheduler.scala:1676
# 26/04/04 10:52:07 INFO DAGScheduler: Submitting 3 missing tasks from ResultStage 10 (MapPartitionsRDD[25] at saveAsTextFile at NativeMethodAccessorImpl.java:0) (first 15 tasks are for partitions Vector(0, 1, 2))
# 26/04/04 10:52:07 INFO TaskSchedulerImpl: Adding task set 10.0 with 3 tasks resource profile 0
# 26/04/04 10:52:07 INFO TaskSetManager: Starting task 0.0 in stage 10.0 (TID 20) (f835b7231555,executor driver, partition 0, NODE_LOCAL, 9449 bytes)
# 26/04/04 10:52:07 INFO TaskSetManager: Starting task 1.0 in stage 10.0 (TID 21) (f835b7231555,executor driver, partition 1, NODE_LOCAL, 9449 bytes)
# 26/04/04 10:52:07 INFO Executor: Running task 0.0 in stage 10.0 (TID 20)
# 26/04/04 10:52:07 INFO Executor: Running task 1.0 in stage 10.0 (TID 21)
# 26/04/04 10:52:07 INFO ShuffleBlockFetcherIterator: Getting 3 (13.7 KiB) non-empty blocks including 3 (13.7 KiB) local and 0 (0.0 B) host-local and 0 (0.0 B) push-merged-local and 0 (0.0 B) remote blocks
# 26/04/04 10:52:07 INFO ShuffleBlockFetcherIterator: Started 0 remote fetches in 2 ms
# 26/04/04 10:52:07 INFO HadoopMapRedCommitProtocol: Using output committer class org.apache.hadoop.mapred.FileOutputCommitter
# 26/04/04 10:52:07 INFO FileOutputCommitter: File Output Committer Algorithm version is 1
# 26/04/04 10:52:07 INFO FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 26/04/04 10:52:07 INFO ShuffleBlockFetcherIterator: Getting 3 (12.9 KiB) non-empty blocks including 3 (12.9 KiB) local and 0 (0.0 B) host-local and 0 (0.0 B) push-merged-local and 0 (0.0 B) remote blocks
# 26/04/04 10:52:07 INFO ShuffleBlockFetcherIterator: Started 0 remote fetches in 3 ms
# 26/04/04 10:52:07 INFO HadoopMapRedCommitProtocol: Using output committer class org.apache.hadoop.mapred.FileOutputCommitter
# 26/04/04 10:52:07 INFO FileOutputCommitter: File Output Committer Algorithm version is 1
# 26/04/04 10:52:07 INFO FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 26/04/04 10:52:08 INFO PythonRunner: Times: total = 423, boot = -3188, init = 3608, finish = 3
# 26/04/04 10:52:08 INFO PythonRunner: Times: total = 437, boot = -142, init = 573, finish = 6
# 26/04/04 10:52:08 INFO FileOutputCommitter: Saved output of task 'attempt_20260404105150722132641453140763_0025_m_000000_0' to file:/content/drive/MyDrive/Большие_данные_лр1/first_station_trips/_temporary/0/task_20260404105150722132641453140763_0025_m_000000
# 26/04/04 10:52:08 INFO SparkHadoopMapRedUtil: attempt_20260404105150722132641453140763_0025_m_000000_0: Committed. Elapsed time: 30 ms.
# 26/04/04 10:52:08 INFO Executor: Finished task 0.0 in stage 10.0 (TID 20). 2551 bytes result sent to driver
# 26/04/04 10:52:08 INFO FileOutputCommitter: Saved output of task 'attempt_20260404105150722132641453140763_0025_m_000001_0' to file:/content/drive/MyDrive/Большие_данные_лр1/first_station_trips/_temporary/0/task_20260404105150722132641453140763_0025_m_000001
# 26/04/04 10:52:08 INFO TaskSetManager: Starting task 2.0 in stage 10.0 (TID 22) (f835b7231555,executor driver, partition 2, NODE_LOCAL, 9449 bytes)
# 26/04/04 10:52:08 INFO SparkHadoopMapRedUtil: attempt_20260404105150722132641453140763_0025_m_000001_0: Committed. Elapsed time: 17 ms.
# 26/04/04 10:52:08 INFO Executor: Running task 2.0 in stage 10.0 (TID 22)
# 26/04/04 10:52:08 INFO Executor: Finished task 1.0 in stage 10.0 (TID 21). 2551 bytes result sent to driver
# 26/04/04 10:52:08 INFO TaskSetManager: Finished task 0.0 in stage 10.0 (TID 20) in 547 ms on f835b7231555 (executor driver) (1/3)
# 26/04/04 10:52:08 INFO TaskSetManager: Finished task 1.0 in stage 10.0 (TID 21) in 550 ms on f835b7231555 (executor driver) (2/3)
# 26/04/04 10:52:08 INFO ShuffleBlockFetcherIterator: Getting 3 (17.1 KiB) non-empty blocks including 3 (17.1 KiB) local and 0 (0.0 B) host-local and 0 (0.0 B) push-merged-local and 0 (0.0 B) remote blocks
# 26/04/04 10:52:08 INFO ShuffleBlockFetcherIterator: Started 0 remote fetches in 1 ms
# 26/04/04 10:52:08 INFO HadoopMapRedCommitProtocol: Using output committer class org.apache.hadoop.mapred.FileOutputCommitter
# 26/04/04 10:52:08 INFO FileOutputCommitter: File Output Committer Algorithm version is 1
# 26/04/04 10:52:08 INFO FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 26/04/04 10:52:08 INFO PythonRunner: Times: total = 193, boot = -59, init = 250, finish = 2
# 26/04/04 10:52:08 INFO FileOutputCommitter: Saved output of task 'attempt_20260404105150722132641453140763_0025_m_000002_0' to file:/content/drive/MyDrive/Большие_данные_лр1/first_station_trips/_temporary/0/task_20260404105150722132641453140763_0025_m_000002
# 26/04/04 10:52:08 INFO SparkHadoopMapRedUtil: attempt_20260404105150722132641453140763_0025_m_000002_0: Committed. Elapsed time: 8 ms.
# 26/04/04 10:52:08 INFO Executor: Finished task 2.0 in stage 10.0 (TID 22). 2594 bytes result sent to driver
# 26/04/04 10:52:08 INFO TaskSetManager: Finished task 2.0 in stage 10.0 (TID 22) in 267 ms on f835b7231555 (executor driver) (3/3)
# 26/04/04 10:52:08 INFO TaskSchedulerImpl: Removed TaskSet 10.0 whose tasks have all completed, from pool
# 26/04/04 10:52:08 INFO DAGScheduler: ResultStage 10 (runJob at SparkHadoopWriter.scala:85) finished in 862 ms
# 26/04/04 10:52:08 INFO DAGScheduler: Job 5 is finished. Cancelling potential speculative or zombie tasks for this job
# 26/04/04 10:52:08 INFO TaskSchedulerImpl: Canceling stage 10
# 26/04/04 10:52:08 INFO TaskSchedulerImpl: Killing all running tasks in stage 10: Stage finished
# 26/04/04 10:52:08 INFO DAGScheduler: Job 5 finished: runJob at SparkHadoopWriter.scala:85, took 18184.001436 ms
# 26/04/04 10:52:08 INFO SparkHadoopWriter: Start to commit write Job job_20260404105150722132641453140763_0025.
# 26/04/04 10:52:08 INFO SparkHadoopWriter: Write Job job_20260404105150722132641453140763_0025 committed. Elapsed time: 157 ms.
# 26/04/04 10:52:08 INFO SparkContext: SparkContext is stopping with exitCode 0 from stop at NativeMethodAccessorImpl.java:0.
# 26/04/04 10:52:08 INFO SparkUI: Stopped Spark web UI at http://f835b7231555:4040
# 26/04/04 10:52:08 INFO MapOutputTrackerMasterEndpoint: MapOutputTrackerMasterEndpoint stopped!
# 26/04/04 10:52:08 INFO MemoryStore: MemoryStore cleared
# 26/04/04 10:52:08 INFO BlockManager: BlockManager stopped
# 26/04/04 10:52:08 INFO BlockManagerMaster: BlockManagerMaster stopped
# 26/04/04 10:52:08 INFO OutputCommitCoordinator$OutputCommitCoordinatorEndpoint: OutputCommitCoordinator stopped!
# 26/04/04 10:52:08 INFO SparkContext: Successfully stopped SparkContext
# 26/04/04 10:52:09 INFO ShutdownHookManager: Shutdown hook called
# 26/04/04 10:52:09 INFO ShutdownHookManager: Deleting directory /tmp/spark-5d50e029-fb17-4e04-bb3d-1006f202e46b
# 26/04/04 10:52:09 INFO ShutdownHookManager: Deleting directory /tmp/spark-5e0fc390-e10b-49c1-8a6d-0b02b65e14d6
# 26/04/04 10:52:09 INFO ShutdownHookManager: Deleting directory /tmp/spark-5d50e029-fb17-4e04-bb3d-1006f202e46b/pyspark-f5160e2d-3c3e-461a-ad0c-de88ad28919b

# %% [markdown]
# ## Решение задач

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("BikeAnalysis_Tasks").master("local[*]").getOrCreate()

trips_df = spark.read.csv("/content/drive/MyDrive/Большие_данные_лр1/data/trips.csv", header=True, inferSchema=True)
stations_df = spark.read.csv("/content/drive/MyDrive/Большие_данные_лр1/data/stations.csv", header=True, inferSchema=True)

trips_df.createOrReplaceTempView("trips")
stations_df.createOrReplaceTempView("stations")

# %% [markdown]
# ## Найти велосипед с максимальным временем пробега.

# %%
max_running_time_bike = spark.sql("""
SELECT bike_id, SUM(duration) as total_duration
FROM trips
GROUP BY bike_id
ORDER BY total_duration DESC
LIMIT 1
""")

max_running_time_bike.show()
# Out:
# +-------+--------------+
# |bike_id|total_duration|
# +-------+--------------+
# |    535|      18611693|
# +-------+--------------+

# %% [markdown]
# ## Найти наибольшее геодезическое расстояние между станциями.

# %%
max_geo_length = spark.sql("""
SELECT
    s1.name AS station_A,
    s2.name AS station_B,
    (6371 * ACOS(
        COS(RADIANS(s1.lat)) * COS(RADIANS(s2.lat)) * COS(RADIANS(s2.long) - RADIANS(s1.long)) +
        SIN(RADIANS(s1.lat)) * SIN(RADIANS(s2.lat))
    )) AS distance_km
FROM stations s1 CROSS JOIN stations s2
WHERE s1.id < s2.id
ORDER BY distance_km DESC
LIMIT 1
""")
max_geo_length.show()
# Out:
# +--------------------+--------------------+-----------------+
# |           station_A|           station_B|      distance_km|
# +--------------------+--------------------+-----------------+
# |SJSU - San Salvad...|Embarcadero at Sa...|69.92087595421542|
# +--------------------+--------------------+-----------------+

# %% [markdown]
# ## Найти путь велосипеда с максимальным временем пробега через станции.

# %%
bike_path = spark.sql("""
SELECT start_date, start_station_name, end_station_name
FROM trips
WHERE bike_id = (
    SELECT bike_id
    FROM trips
    GROUP BY bike_id
    ORDER BY SUM(duration) DESC
    LIMIT 1
)
ORDER BY TO_TIMESTAMP(start_date, 'M/d/yyyy H:mm')
""")
bike_path.show(50, truncate=False)
# Out:
# +---------------+---------------------------------------------+----------------------------------------+
# |start_date     |start_station_name                           |end_station_name                        |
# +---------------+---------------------------------------------+----------------------------------------+
# |8/29/2013 19:32|Post at Kearney                              |San Francisco Caltrain (Townsend at 4th)|
# |8/29/2013 21:38|San Francisco Caltrain (Townsend at 4th)     |San Francisco Caltrain 2 (330 Townsend) |
# |8/30/2013 8:40 |San Francisco Caltrain 2 (330 Townsend)      |Market at Sansome                       |
# |8/30/2013 9:10 |Market at Sansome                            |2nd at South Park                       |
# |9/1/2013 12:58 |2nd at Townsend                              |Davis at Jackson                        |
# |9/5/2013 11:59 |San Francisco City Hall                      |Civic Center BART (7th at Market)       |
# |9/6/2013 10:55 |Civic Center BART (7th at Market)            |Post at Kearney                         |
# |9/6/2013 13:58 |Post at Kearney                              |Embarcadero at Sansome                  |
# |9/6/2013 15:07 |Embarcadero at Sansome                       |Washington at Kearney                   |
# |9/6/2013 23:22 |Washington at Kearney                        |Market at Sansome                       |
# |9/7/2013 12:08 |Market at Sansome                            |Market at Sansome                       |
# |9/8/2013 10:56 |Market at Sansome                            |2nd at Folsom                           |
# |9/8/2013 13:15 |2nd at Folsom                                |2nd at Townsend                         |
# |9/9/2013 8:31  |Temporary Transbay Terminal (Howard at Beale)|2nd at Townsend                         |
# |9/9/2013 8:40  |2nd at Townsend                              |Embarcadero at Sansome                  |
# |9/9/2013 9:41  |Embarcadero at Sansome                       |Clay at Battery                         |
# |9/9/2013 13:44 |Clay at Battery                              |Harry Bridges Plaza (Ferry Building)    |
# |9/9/2013 13:52 |Harry Bridges Plaza (Ferry Building)         |Clay at Battery                         |
# |9/9/2013 16:51 |Clay at Battery                              |San Francisco Caltrain (Townsend at 4th)|
# |9/10/2013 8:44 |San Francisco Caltrain (Townsend at 4th)     |Steuart at Market                       |
# |9/10/2013 9:41 |Steuart at Market                            |2nd at Townsend                         |
# |9/11/2013 12:24|2nd at Townsend                              |Harry Bridges Plaza (Ferry Building)    |
# |9/11/2013 12:34|Harry Bridges Plaza (Ferry Building)         |Townsend at 7th                         |
# |9/11/2013 13:11|Townsend at 7th                              |San Francisco Caltrain (Townsend at 4th)|
# |9/12/2013 9:21 |San Francisco Caltrain 2 (330 Townsend)      |San Francisco Caltrain 2 (330 Townsend) |
# |9/12/2013 10:18|San Francisco Caltrain 2 (330 Townsend)      |Townsend at 7th                         |
# |9/12/2013 16:26|Steuart at Market                            |San Francisco Caltrain (Townsend at 4th)|
# |9/12/2013 18:45|San Francisco Caltrain (Townsend at 4th)     |2nd at South Park                       |
# |9/12/2013 19:36|2nd at South Park                            |5th at Howard                           |
# |9/13/2013 12:42|Post at Kearney                              |San Francisco Caltrain 2 (330 Townsend) |
# |9/14/2013 13:18|2nd at Folsom                                |Mechanics Plaza (Market at Battery)     |
# |9/15/2013 9:23 |Mechanics Plaza (Market at Battery)          |Powell at Post (Union Square)           |
# |9/15/2013 12:55|Powell at Post (Union Square)                |Powell at Post (Union Square)           |
# |9/15/2013 14:36|Powell at Post (Union Square)                |5th at Howard                           |
# |9/16/2013 9:06 |Powell at Post (Union Square)                |Mechanics Plaza (Market at Battery)     |
# |9/16/2013 11:59|Mechanics Plaza (Market at Battery)          |Market at 4th                           |
# |9/16/2013 13:30|Market at 4th                                |Market at 10th                          |
# |9/16/2013 17:40|Market at 10th                               |San Francisco Caltrain (Townsend at 4th)|
# |9/16/2013 18:28|San Francisco Caltrain (Townsend at 4th)     |Civic Center BART (7th at Market)       |
# |9/16/2013 23:19|Civic Center BART (7th at Market)            |Beale at Market                         |
# |9/17/2013 8:21 |Beale at Market                              |Golden Gate at Polk                     |
# |9/18/2013 12:49|Golden Gate at Polk                          |5th at Howard                           |
# |9/18/2013 17:42|5th at Howard                                |San Francisco Caltrain (Townsend at 4th)|
# |9/18/2013 21:31|Townsend at 7th                              |San Francisco Caltrain (Townsend at 4th)|
# |9/19/2013 8:11 |San Francisco Caltrain (Townsend at 4th)     |Mechanics Plaza (Market at Battery)     |
# |9/19/2013 8:52 |Mechanics Plaza (Market at Battery)          |Market at 10th                          |
# |9/19/2013 15:46|Market at 10th                               |Market at 4th                           |
# |9/19/2013 21:20|Market at 4th                                |San Francisco Caltrain (Townsend at 4th)|
# |9/21/2013 16:54|San Francisco Caltrain 2 (330 Townsend)      |5th at Howard                           |
# |9/23/2013 11:56|San Francisco Caltrain 2 (330 Townsend)      |Harry Bridges Plaza (Ferry Building)    |
# +---------------+---------------------------------------------+----------------------------------------+
# only showing top 50 rows

# %% [markdown]
# ## Найти количество велосипедов в системе.

# %%
total_bikes = spark.sql("""
SELECT COUNT(DISTINCT bike_id) AS total_bikes
FROM trips
""")
total_bikes.show()
# Out:
# +-----------------------+
# |count(DISTINCT bike_id)|
# +-----------------------+
# |                    700|
# +-----------------------+

# %% [markdown]
# ## Найти пользователей потративших на поездки более 3 часов.

# %%
more_3h_users = spark.sql("""
SELECT
    id AS trip_id,
    duration,
    start_date,
    subscription_type,
    zip_code
FROM trips
WHERE duration > 10800
ORDER BY duration DESC
""")
more_3h_users.show(50, truncate=False)
# в датасете нет id пользователей, поэтому выводится информация которая известна о пользователях через поездки
# Out:
# +-------+--------+----------------+-----------------+--------+
# |trip_id|duration|start_date      |subscription_type|zip_code|
# +-------+--------+----------------+-----------------+--------+
# |568474 |17270400|12/6/2014 21:59 |Customer         |95531   |
# |825850 |2137000 |6/28/2015 21:50 |Customer         |97213   |
# |750192 |1852590 |5/2/2015 6:17   |Subscriber       |94024   |
# |841176 |1133540 |7/10/2015 10:35 |Customer         |94306   |
# |111309 |722236  |11/30/2013 13:29|Customer         |94301   |
# |522337 |720454  |10/30/2014 8:29 |Customer         |94010   |
# |323594 |716480  |6/13/2014 16:57 |Subscriber       |94131   |
# |361321 |715339  |7/13/2014 5:50  |Customer         |nil     |
# |774999 |688899  |5/20/2015 15:27 |Customer         |nil     |
# |635260 |655939  |2/8/2015 3:05   |Customer         |89451   |
# |237942 |644771  |4/6/2014 3:37   |Customer         |94014   |
# |129504 |619322  |12/18/2013 9:16 |Subscriber       |94041   |
# |745640 |611240  |4/29/2015 9:41  |Customer         |81      |
# |635263 |602338  |2/8/2015 3:09   |Customer         |89451   |
# |32121  |597517  |9/23/2013 18:24 |Customer         |95051   |
# |779645 |594550  |5/24/2015 13:33 |Customer         |95118   |
# |166010 |586356  |1/25/2014 20:00 |Customer         |94303   |
# |421286 |560792  |8/23/2014 9:48  |Customer         |94040   |
# |812544 |552697  |6/18/2015 10:45 |Customer         |90024   |
# |661326 |531240  |2/27/2015 15:45 |Customer         |95112   |
# |284683 |517856  |5/14/2014 21:14 |Customer         |94040   |
# |644642 |505483  |2/14/2015 17:30 |Customer         |95136   |
# |830135 |502617  |7/1/2015 14:12  |Customer         |nil     |
# |473196 |489435  |9/28/2014 18:21 |Customer         |95116   |
# |417776 |464952  |8/21/2014 6:16  |Customer         |94102   |
# |504411 |457110  |10/17/2014 18:49|Customer         |94582   |
# |62246  |429384  |10/17/2013 16:06|Customer         |43113   |
# |237943 |411846  |4/6/2014 3:38   |Customer         |94014   |
# |566582 |410157  |12/4/2014 21:55 |Customer         |nil     |
# |626177 |405271  |1/30/2015 21:25 |Customer         |95112   |
# |566610 |404503  |12/4/2014 23:28 |Customer         |92705   |
# |566584 |403837  |12/4/2014 22:01 |Customer         |nil     |
# |575758 |378964  |12/14/2014 6:55 |Customer         |94709   |
# |505416 |352090  |10/19/2014 13:05|Subscriber       |94103   |
# |681679 |350903  |3/14/2015 9:43  |Customer         |90290   |
# |364841 |348910  |7/15/2014 16:23 |Customer         |94041   |
# |815111 |348211  |6/20/2015 7:21  |Customer         |94102   |
# |880372 |346545  |8/7/2015 12:42  |Customer         |nil     |
# |311114 |329715  |6/4/2014 17:58  |Customer         |33062   |
# |36617  |329456  |9/26/2013 20:51 |Customer         |94306   |
# |450239 |324775  |9/12/2014 13:46 |Customer         |3552    |
# |589514 |319017  |1/2/2015 14:37  |Customer         |92866   |
# |364842 |318236  |7/15/2014 16:23 |Customer         |94041   |
# |21760  |309479  |9/14/2013 18:21 |Customer         |95112   |
# |560258 |305382  |11/28/2014 8:20 |Customer         |8001    |
# |150269 |303271  |1/11/2014 20:16 |Customer         |94110   |
# |138946 |296045  |12/31/2013 9:43 |Customer         |NULL    |
# |582110 |295512  |12/21/2014 1:35 |Customer         |94568   |
# |784002 |295377  |5/28/2015 8:44  |Subscriber       |94002   |
# |690470 |289873  |3/20/2015 8:24  |Subscriber       |94114   |
# +-------+--------+----------------+-----------------+--------+
# only showing top 50 rows
